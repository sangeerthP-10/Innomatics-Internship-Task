# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Innomatics-Internship-Task/blob/main/Task_4_Feb_Internship_Function_with_Loops_%E2%80%93_2_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Mobile Recharge Validation System
#
#  Problem Statement
#
# Create a function to validate a mobile recharge request.
#
# Rules:
#
# Recharge amount must be ≥ ₹50
#
#
# Valid plans: 199, 299, 399, 599
#
#
# User should be allowed to retry if invalid

# %%
def mobile_recharge():
    valid_plan = [199, 299, 399, 599]

    while True:
        recharge_amount = int(input("Enter the recharge amount: ₹"))

        if recharge_amount < 50:
            print("Recharge amount must be at least ₹50")

        elif recharge_amount not in valid_plan:
            print("Invalid plan selected")
            print("Available plans: 199, 299, 399, 599")

        else:
            print("Recharge successful")
            break


mobile_recharge()
# Out:
# Enter the recharge amount: ₹30
# Recharge amount must be at least ₹50
# Enter the recharge amount: ₹200
# Invalid plan selected
# Available plans: 199, 299, 399, 599
# Enter the recharge amount: ₹199
# Recharge successful

# %% [markdown]
# Problem 2: Inventory Reorder Alert System
#
# Problem Statement
#
# Given a dictionary of products and stock quantities:
#
# Print Reorder Alert if stock < 15
#
#
# Print Stock OK otherwise

# %%
def store(stock_data):
    for product, quantity in stock_data.items():
        if quantity < 15:
            print(f"{product} : Reorder Alert (Stock: {quantity})")
        else:
            print(f"{product} : Stock OK (Stock: {quantity})")


item= {
    "Rice": 25,
    "Sugar": 10,
    "Oil": 18,
    "Salt": 5,
    "Wheat": 30
}

store(item)
# Out:
# Rice : Stock OK (Stock: 25)
# Sugar : Reorder Alert (Stock: 10)
# Oil : Stock OK (Stock: 18)
# Salt : Reorder Alert (Stock: 5)
# Wheat : Stock OK (Stock: 30)

# %% [markdown]
#  Problem 3: Student Result Processing System
#
# Problem Statement
#
# Create a function that:
#
# Accepts a list of student marks
#
#
# Calculates average marks
#
#
# Prints Pass if average ≥ 50 else Fail

# %%
def results(marks):
    total = 0
    for mark in marks:
        total += mark

    average = total / len(marks)
    print("Average Marks:", average)

    if average >= 50:
        return "Pass"
    else:
        return "Fail"

marks_list = []

n = int(input("Enter number of subjects: "))

for i in range(n):
    mark = float(input(f"Enter marks for subject {i+1}: "))
    marks_list.append(mark)

print("Result:", results(marks_list))
# Out:
# Enter number of subjects: 5
# Enter marks for subject 1: 30
# Enter marks for subject 2: 40
# Enter marks for subject 3: 59
# Enter marks for subject 4: 35
# Enter marks for subject 5: 78
# Average Marks: 48.4
# Result: Fail

# %% [markdown]
# Problem 4: Cab Fare Estimator with Retry Option
#
# Problem Statement
#
#
# Create a cab fare calculator:
# Base fare = ₹50
#
#
# ₹12 per km
#
#
# Peak hour → 25% extra
#
#
# Allow retry using while loop

# %%
def calculate_fare(distance, peak):
    base_fare = 50
    fare = base_fare + (12 * distance)

    if peak.lower() == "yes":
        fare = fare + (fare * 0.25)

    return fare

while True:

    distance_input = input("Enter distance in km: ")

    if distance_input.replace('.', '', 1).isdigit():
        distance = float(distance_input)

        peak = input("Is it peak hour? (yes/no): ")

        if peak.lower() != "yes" and peak.lower() != "no":
            print("Please enter 'yes' or 'no' for peak hour.")
            continue

        total_fare = calculate_fare(distance, peak)
        print("Total Fare: ₹", total_fare)

        retry = input("Do you want to retry? (yes/no): ")
        if retry.lower() != "yes":
            break
    else:
        print("Please enter a valid numeric distance.")
# Out:
# Enter distance in km: 20
# Is it peak hour? (yes/no): yes
# Total Fare: ₹ 362.5
# Do you want to retry? (yes/no): yes
# Enter distance in km: 20
# Is it peak hour? (yes/no): no
# Total Fare: ₹ 290.0
# Do you want to retry? (yes/no): yes
# Enter distance in km: abv
# Please enter a valid numeric distance.
# Enter distance in km: 20.5
# Is it peak hour? (yes/no): yes
# Total Fare: ₹ 370.0
# Do you want to retry? (yes/no): no

# %% [markdown]
# Problem 5: Employee Attendance Eligibility Checker
#
# Problem Statement:
#
# Create a function that:
#
# Accepts attendance list ("P", "A")
#
#
# Calculates attendance percentage
#
#
# Returns Eligible if ≥ 75% else Not Eligible

# %%
def check_eligibility(attendance):
    present_days = 0

    for day in attendance:
        if day.upper() == "P":
            present_days += 1

    percentage = (present_days / len(attendance)) * 100

    if percentage >= 75:
        return "Eligible"
    else:
        return "Not Eligible"


attendance_input = input("Enter attendance (P/A separated by space): ")

attendance_list = attendance_input.split()

print("Attendance Percentage:",
      (attendance_list.count("P") / len(attendance_list)) * 100)

print("Status:", check_eligibility(attendance_list))
# Out:
# Enter attendance (P/A separated by space): P A P A P P P
# Attendance Percentage: 71.42857142857143
# Status: Not Eligible

# %% [markdown]
# Problem 6: Password Strength Checker
#
# Problem Statement
#
# Create a function to check password strength.
# Rules:
#
# Minimum length = 8
#
#
# Must contain at least one digit
#
#
# Must contain at least one special character (@#$)

# %%
def check_password(password):

    if len(password) < 8:
        return "Weak Password (Minimum 8 characters required)"

    has_digit = False
    has_special = False

    for char in password:
        if char.isdigit():
            has_digit = True
        if char in "@#$":
            has_special = True

    if has_digit and has_special:
        return "Strong Password"
    else:
        return "Weak Password (Must contain at least one digit and one special character @#$)"

password_input = input("Enter your password: ")

print(check_password(password_input))
# Out:
# Enter your password: sANGEERTH@1234
# Strong Password
