# %% [markdown]
# <a href="https://colab.research.google.com/github/sangeerthP-10/Innomatics-Internship-Task/blob/main/Logic_Building_Task_%E2%80%93_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem 1: Unique Words in a Sentence
#
# Problem Statement:
#
# Given a sentence, identify all unique words and display:
#
# The count of unique words
#
# The unique words themselves

# %%
sentence="python is easy and python is powerful"
word=sentence.split(" ")
unique_word=set(word)
print(f"Unique words count : {len(unique_word)}")
print(f"Unique words : {unique_word}")
# Out:
# Unique words count : 5
# Unique words : {'and', 'python', 'is', 'easy', 'powerful'}

# %% [markdown]
# Problem 2: Highest Salary from Employee Data
#
# Problem Statement
#
# Store employee names and their salaries, and determine which employee has the highest salary.

# %%
employees = {
    "Ravi": 75000,
    "Anita": 68000,
    "Kiran": 72000
}

highest_employee = max(employees, key=employees.get)
highest_salary = employees[highest_employee]

print("Highest Salary:", highest_employee, "-", highest_salary)
# Out:
# Highest Salary: Ravi - 75000

# %% [markdown]
# Problem 3: Find Maximum and Minimum Values
#
# Problem Statement :
#
# Find the maximum and minimum values from a list of numbers.

# %%
numbers = [45, 22, 89, 10, 66]

maximum = numbers[0]
minimum = numbers[0]

for num in numbers:
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

print("List:", numbers)
print("Max:", maximum)
print("Min:", minimum)
# Out:
# List: [45, 22, 89, 10, 66]
# Max: 89
# Min: 10

# %% [markdown]
# Problem 4: Count Products Above a Price Threshold
#
# Problem Statement
#
# Count how many products have a price greater than 1000.

# %%
prices = [450, 1200, 899, 1500, 300]
count=0
for price in prices:
  if price>1000:
    count+=1
print(f"Products above 1000 :{count}")
# Out:
# Products above 1000 :2

# %% [markdown]
# Problem 5: Calculate Attendance Percentage
#
# Problem Statement:
#
# Calculate the attendance percentage from a list containing "P" (Present) and "A" (Absent).

# %%
attendance = ["P", "P", "A", "P", "P"]
total_days=len(attendance)
present=0
absent=0

for x in attendance:
  if x=="P":
    present+=1
  else:
    absent+=1

attendace_percentage=present/total_days*100
print(f"Attendance Percentage : {attendace_percentage}")
# Out:
# Attendance Percentage : 80.0

# %% [markdown]
# Problem 6: Remove Duplicate Phone Numbers
#
# Problem Statement:
#
# You are given a list of phone numbers that may contain duplicates. Write a Python program to remove duplicate phone numbers and display only the unique phone numbers.

# %%
phone_numbers = [9876543210, 9123456789, 9876543210]
Unique_phone_numbers=set(phone_numbers)

print(f"Unique phone numbers: {Unique_phone_numbers}")
# Out:
# Unique phone numbers: {9876543210, 9123456789}

# %% [markdown]
# Problem 7: Count Character Frequency
#
# Problem Statement
#
# Count how many times each character appears in a given string.

# %%
text = "ppython"
frequency = {}

for char in text:
    if char in frequency:
        frequency[char] += 1
    else:
        frequency[char] = 1

print(frequency)
# Out:
# {'p': 2, 'y': 1, 't': 1, 'h': 1, 'o': 1, 'n': 1}

# %% [markdown]
# Problem 8: Convert List to Tuple
# Problem Statement
# Convert a list into a tuple and display it.

# %%
Lisst=[10,20,30]
tuuple=tuple(Lisst)
print(f"Tuple: {tuuple}")
# Out:
# Tuple: (10, 20, 30)

# %% [markdown]
# Problem 9: Check if a Key Exists in a Dictionary
#
# Problem Statement
#
# Check whether a specific key exists in a dictionary.

# %%
employees = {"Ravi": 75000, "Anita": 68000}
key="Ravi"

if key in employees:
  print("Employee exists")
else:
  print("Does not exist ")
# Out:
# Employee exists

# %% [markdown]
# Problem 10: Calculate Average Marks
#
# Problem Statement:
#
# Calculate the average marks of a student from a list of marks.

# %%
marks = [70, 80, 65, 75]

average = sum(marks) / len(marks)
print("Average Marks:", average)
# Out:
# Average Marks: 72.5
